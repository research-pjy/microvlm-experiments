# %% [markdown]
# # 05 Child language assumption
# Calls `microvlm.experiments.exp05_child_language_assumption.run_exp05_child_language_assumption` only.

# %%
from microvlm.utils.env_check import require_microvlm_env
from microvlm.utils.hydra_compose import compose_config
from microvlm.experiments.exp05_child_language_assumption import run_exp05_child_language_assumption

require_microvlm_env()
cfg = compose_config(config_name="experiment/exp05")
df = run_exp05_child_language_assumption(cfg)
df

# %%
import matplotlib.pyplot as plt

numeric = df.select_dtypes(include="number")
if numeric.shape[1] >= 1:
    ax = numeric.iloc[:, : min(3, numeric.shape[1])].plot(kind="bar", figsize=(8, 4))
    ax.set_title("experiment results")
    plt.tight_layout()
    plt.show()
else:
    display(df)

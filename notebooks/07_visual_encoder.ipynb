# %% [markdown]
# # 07 Visual encoder ambiguity
# Calls `microvlm.experiments.exp07_visual_encoder.run_exp07_visual_encoder` only.

# %%
from microvlm.utils.env_check import require_microvlm_env
from microvlm.utils.hydra_compose import compose_config
from microvlm.experiments.exp07_visual_encoder import run_exp07_visual_encoder

require_microvlm_env()
cfg = compose_config(config_name="experiment/exp07")
df = run_exp07_visual_encoder(cfg)
df
# Out:
#      arch  step       loss  n_params  encoder_frac  final_epoch_mean
# 0  arch_a     0  66.203804   3092016      0.580514         54.182019
# 1  arch_a     1  53.464798   3092016      0.580514         54.182019
# 2  arch_a     2  55.760921   3092016      0.580514         54.182019
# 3  arch_a     3  53.825562   3092016      0.580514         54.182019
# 4  arch_a     4  41.655010   3092016      0.580514         54.182019
# 5  arch_b     0  49.978214   2016176      0.356675         50.224113
# 6  arch_b     1  58.289402   2016176      0.356675         50.224113
# 7  arch_b     2  54.852402   2016176      0.356675         50.224113
# 8  arch_b     3  47.705246   2016176      0.356675         50.224113
# 9  arch_b     4  40.295300   2016176      0.356675         50.224113

# %%
import matplotlib.pyplot as plt

numeric = df.select_dtypes(include="number")
if numeric.shape[1] >= 1:
    ax = numeric.iloc[:, : min(3, numeric.shape[1])].plot(kind="bar", figsize=(8, 4))
    ax.set_title("experiment results")
    plt.tight_layout()
    plt.show()
else:
    display(df)
